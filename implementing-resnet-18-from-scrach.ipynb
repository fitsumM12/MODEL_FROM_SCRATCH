# %%
# IMPORT LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from tensorflow.keras import datasets,models,layers

# %%
# ADDING TF CIFAR10 DATA
from keras.datasets import cifar10
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# %%
# DRAWING SAMPLE VISUALIZATION
plt.imshow(X_train[42])

# %%
# NORMALIZE THE DATA
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2,shuffle = True)

# %%
# ONE HOT ENCODING
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
encoder.fit(Y_train)
Y_train = encoder.transform(Y_train).toarray()
Y_test = encoder.transform(Y_test).toarray()
Y_val =  encoder.transform(Y_val).toarray()

# %%
# DATA AUGMENTATION
from keras.preprocessing.image import ImageDataGenerator
aug = ImageDataGenerator(horizontal_flip=True, 
                         width_shift_range=0.05,
                         height_shift_range=0.05)
aug.fit(X_train)

# %%
# BUILDING RESNET18 FROM SCRATCH
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Conv2D,  MaxPool2D, Flatten, GlobalAveragePooling2D,  BatchNormalization, Layer, Add
from keras.models import Sequential
from keras.models import Model
import tensorflow as tf


class ResnetBlock(Model):
    """
    A standard resnet block.
    """

    def __init__(self, channels: int, down_sample=False):
        """
        channels: same as number of convolution kernels
        """
        super().__init__()

        self.__channels = channels
        self.__down_sample = down_sample
        self.__strides = [2, 1] if down_sample else [1, 1]

        KERNEL_SIZE = (3, 3)
        # use He initialization, instead of Xavier (a.k.a 'glorot_uniform' in Keras), as suggested in [2]
        INIT_SCHEME = "he_normal"

        self.conv_1 = Conv2D(self.__channels, strides=self.__strides[0],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_1 = BatchNormalization()
        self.conv_2 = Conv2D(self.__channels, strides=self.__strides[1],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_2 = BatchNormalization()
        self.merge = Add()

        if self.__down_sample:
            # perform down sampling using stride of 2, according to [1].
            self.res_conv = Conv2D(
                self.__channels, strides=2, kernel_size=(1, 1), kernel_initializer=INIT_SCHEME, padding="same")
            self.res_bn = BatchNormalization()

    def call(self, inputs):
        res = inputs

        x = self.conv_1(inputs)
        x = self.bn_1(x)
        x = tf.nn.relu(x)
        x = self.conv_2(x)
        x = self.bn_2(x)

        if self.__down_sample:
            res = self.res_conv(res)
            res = self.res_bn(res)

        # if not perform down sample, then add a shortcut directly
        x = self.merge([x, res])
        out = tf.nn.relu(x)
        return out


class ResNet18(Model):

    def __init__(self, num_classes, **kwargs):
        """
            num_classes: number of classes in specific classification task.
        """
        super().__init__(**kwargs)
        self.conv_1 = Conv2D(64, (7, 7), strides=2,
                             padding="same", kernel_initializer="he_normal")
        self.init_bn = BatchNormalization()
        self.pool_2 = MaxPool2D(pool_size=(2, 2), strides=2, padding="same")
        self.res_1_1 = ResnetBlock(64)
        self.res_1_2 = ResnetBlock(64)
        self.res_2_1 = ResnetBlock(128, down_sample=True)
        self.res_2_2 = ResnetBlock(128)
        self.res_3_1 = ResnetBlock(256, down_sample=True)
        self.res_3_2 = ResnetBlock(256)
        self.res_4_1 = ResnetBlock(512, down_sample=True)
        self.res_4_2 = ResnetBlock(512)
        self.avg_pool = GlobalAveragePooling2D()
        self.flat = Flatten()
        self.fc = Dense(num_classes, activation="softmax")

    def call(self, inputs):
        out = self.conv_1(inputs)
        out = self.init_bn(out)
        out = tf.nn.relu(out)
        out = self.pool_2(out)
        for res_block in [self.res_1_1, self.res_1_2, self.res_2_1, self.res_2_2, self.res_3_1, self.res_3_2, self.res_4_1, self.res_4_2]:
            out = res_block(out)
        out = self.avg_pool(out)
        out = self.flat(out)
        out = self.fc(out)
        return out

# MODEL INSTANSATION AND COMPILE
model = ResNet18(10)
model.build(input_shape = (None,32,32,3))
from keras.optimizers import SGD
model.compile(optimizer = "adam",loss='categorical_crossentropy', metrics=["accuracy"]) 
model.summary()
# Out:
# WARNING: AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7966f8c1c5d0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "res_net18_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_80 (Conv2D)           multiple                  9472
# _________________________________________________________________
# batch_normalization_80 (Batc multiple                  256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 multiple                  0
# _________________________________________________________________
# resnet_block_32 (ResnetBlock multiple                  74368
# _________________________________________________________________
# resnet_block_33 (ResnetBlock multiple                  74368
# _________________________________________________________________
# resnet_block_34 (ResnetBlock multiple                  231296
# _________________________________________________________________
# resnet_block_35 (ResnetBlock multiple                  296192
# _________________________________________________________________
# resnet_block_36 (ResnetBlock multiple                  921344
# _________________________________________________________________
# resnet_block_37 (ResnetBlock multiple                  1182208
# _________________________________________________________________
# resnet_block_38 (ResnetBlock multiple                  3677696
# _________________________________________________________________
# resnet_block_39 (ResnetBlock multiple                  4723712
# _________________________________________________________________
# global_average_pooling2d_4 ( multiple                  0
# _________________________________________________________________
# flatten_4 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_4 (Dense)              multiple                  5130
# =================================================================
# Total params: 11,196,042
# Trainable params: 11,186,442
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(patience= 8, restore_best_weights=True, monitor="val_acc")
STEPS = len(X_train) / 256
history = model.fit(aug.flow(X_train,Y_train,batch_size = 256), steps_per_epoch=STEPS, batch_size = 256, epochs=50, validation_data=(X_train, Y_train),callbacks=[es])
# Out:
# Epoch 1/50
# 157/156 [==============================] - 20s 130ms/step - loss: 1.6020 - accuracy: 0.4353 - val_loss: 1.9502 - val_accuracy: 0.3122
# Epoch 2/50
# 157/156 [==============================] - 20s 124ms/step - loss: 1.2473 - accuracy: 0.5534 - val_loss: 1.3957 - val_accuracy: 0.5095
# Epoch 3/50
# 157/156 [==============================] - 19s 124ms/step - loss: 1.1042 - accuracy: 0.6032 - val_loss: 1.1176 - val_accuracy: 0.6014
# Epoch 4/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.9762 - accuracy: 0.6524 - val_loss: 1.2397 - val_accuracy: 0.5687
# Epoch 5/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.8844 - accuracy: 0.6870 - val_loss: 0.9186 - val_accuracy: 0.6791
# Epoch 6/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.8163 - accuracy: 0.7110 - val_loss: 0.9263 - val_accuracy: 0.6745
# Epoch 7/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.7542 - accuracy: 0.7319 - val_loss: 0.8521 - val_accuracy: 0.7054
# Epoch 8/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.7072 - accuracy: 0.7479 - val_loss: 1.0811 - val_accuracy: 0.6304
# Epoch 9/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.6620 - accuracy: 0.7646 - val_loss: 0.8391 - val_accuracy: 0.7213
# Epoch 10/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.6189 - accuracy: 0.7820 - val_loss: 0.9230 - val_accuracy: 0.6948
# Epoch 11/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.5915 - accuracy: 0.7909 - val_loss: 0.7179 - val_accuracy: 0.7514
# Epoch 12/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.5519 - accuracy: 0.8062 - val_loss: 0.5824 - val_accuracy: 0.7939
# Epoch 13/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.5163 - accuracy: 0.8161 - val_loss: 0.8757 - val_accuracy: 0.7143
# Epoch 14/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.4995 - accuracy: 0.8225 - val_loss: 0.8088 - val_accuracy: 0.7351
# Epoch 15/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.4612 - accuracy: 0.8368 - val_loss: 0.5576 - val_accuracy: 0.8052
# Epoch 16/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.4399 - accuracy: 0.8433 - val_loss: 0.4633 - val_accuracy: 0.8364
# Epoch 17/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.3989 - accuracy: 0.8601 - val_loss: 0.4582 - val_accuracy: 0.8378
# Epoch 18/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.3976 - accuracy: 0.8592 - val_loss: 0.3847 - val_accuracy: 0.8638
# Epoch 19/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.3651 - accuracy: 0.8714 - val_loss: 0.4159 - val_accuracy: 0.8557
# Epoch 20/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.3472 - accuracy: 0.8769 - val_loss: 0.3461 - val_accuracy: 0.8807
# Epoch 21/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.3354 - accuracy: 0.8822 - val_loss: 0.3300 - val_accuracy: 0.8849
# Epoch 22/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.3050 - accuracy: 0.8924 - val_loss: 0.5596 - val_accuracy: 0.8217
# Epoch 23/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.2839 - accuracy: 0.8989 - val_loss: 0.4078 - val_accuracy: 0.8595
# Epoch 24/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.2782 - accuracy: 0.9028 - val_loss: 0.3850 - val_accuracy: 0.8681
# Epoch 25/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.2575 - accuracy: 0.9082 - val_loss: 0.3300 - val_accuracy: 0.8822
# Epoch 26/50
# 157/156 [==============================] - 20s 126ms/step - loss: 0.2479 - accuracy: 0.9126 - val_loss: 0.5424 - val_accuracy: 0.8203
# Epoch 27/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.2404 - accuracy: 0.9161 - val_loss: 0.3440 - val_accuracy: 0.8793
# Epoch 28/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.2256 - accuracy: 0.9211 - val_loss: 0.2682 - val_accuracy: 0.9059
# Epoch 29/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.2072 - accuracy: 0.9277 - val_loss: 0.3533 - val_accuracy: 0.8767
# Epoch 30/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.2020 - accuracy: 0.9289 - val_loss: 0.5599 - val_accuracy: 0.8282
# Epoch 31/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1873 - accuracy: 0.9332 - val_loss: 0.4497 - val_accuracy: 0.8565
# Epoch 32/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1899 - accuracy: 0.9336 - val_loss: 0.2762 - val_accuracy: 0.9071
# Epoch 33/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1716 - accuracy: 0.9394 - val_loss: 0.3651 - val_accuracy: 0.8824
# Epoch 34/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1734 - accuracy: 0.9380 - val_loss: 0.3388 - val_accuracy: 0.8864
# Epoch 35/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.1595 - accuracy: 0.9437 - val_loss: 0.2891 - val_accuracy: 0.9031
# Epoch 36/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1528 - accuracy: 0.9455 - val_loss: 0.2109 - val_accuracy: 0.9262
# Epoch 37/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1480 - accuracy: 0.9473 - val_loss: 0.1843 - val_accuracy: 0.9341
# Epoch 38/50
# 157/156 [==============================] - 19s 122ms/step - loss: 0.1412 - accuracy: 0.9492 - val_loss: 0.1675 - val_accuracy: 0.9412
# Epoch 39/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.1349 - accuracy: 0.9525 - val_loss: 0.2577 - val_accuracy: 0.9151
# Epoch 40/50
# 157/156 [==============================] - 20s 124ms/step - loss: 0.1352 - accuracy: 0.9525 - val_loss: 0.3831 - val_accuracy: 0.8748
# Epoch 41/50
# 157/156 [==============================] - 19s 122ms/step - loss: 0.1295 - accuracy: 0.9547 - val_loss: 0.1916 - val_accuracy: 0.9359
# Epoch 42/50
# 157/156 [==============================] - 20s 125ms/step - loss: 0.1255 - accuracy: 0.9549 - val_loss: 0.1684 - val_accuracy: 0.9388
# Epoch 43/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.1198 - accuracy: 0.9581 - val_loss: 0.2260 - val_accuracy: 0.9236
# Epoch 44/50
# 157/156 [==============================] - 19s 122ms/step - loss: 0.1130 - accuracy: 0.9607 - val_loss: 0.2354 - val_accuracy: 0.9215
# Epoch 45/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.1215 - accuracy: 0.9577 - val_loss: 0.2291 - val_accuracy: 0.9254
# Epoch 46/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1125 - accuracy: 0.9606 - val_loss: 0.2856 - val_accuracy: 0.9090
# Epoch 47/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1083 - accuracy: 0.9623 - val_loss: 0.1388 - val_accuracy: 0.9526
# Epoch 48/50
# 157/156 [==============================] - 19s 124ms/step - loss: 0.1046 - accuracy: 0.9636 - val_loss: 0.1452 - val_accuracy: 0.9497
# Epoch 49/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.1053 - accuracy: 0.9632 - val_loss: 0.1914 - val_accuracy: 0.9339
# Epoch 50/50
# 157/156 [==============================] - 19s 123ms/step - loss: 0.0961 - accuracy: 0.9668 - val_loss: 0.1846 - val_accuracy: 0.9385

# %%
# MODEL TRAINING CURVE
def plotmodelhistory(history): 
    fig, axs = plt.subplots(1,2,figsize=(15,5)) 
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy']) 
    axs[0].plot(history.history['val_accuracy']) 
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy') 
    axs[0].set_xlabel('Epoch')
    
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss']) 
    axs[1].plot(history.history['val_loss']) 
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss') 
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

# list all data in history
print(history.history.keys())
plotmodelhistory(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# MODEL PERFORMANCE EVALUATION
ModelLoss, ModelAccuracy = model.evaluate(X_test, Y_test)
print('Model Loss is {}'.format(ModelLoss))
print('Model Accuracy is {}'.format(ModelAccuracy))
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 1.2138 - accuracy: 0.7472
# Model Loss is 1.2137712240219116
# Model Accuracy is 0.7472000122070312
